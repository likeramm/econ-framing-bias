# %% [markdown]
# # 02. 프레이밍 분류 모델 학습
#
# ## 목표
# - KLUE-RoBERTa Fine-tuning (6가지 프레이밍 유형)
# - KcELECTRA 감성 강도 분석 모델 학습
# - 모델 성능 평가 (F1 >= 0.80 목표)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from datasets import Dataset
import pandas as pd

# %%
# TODO: 모델 학습 구현
