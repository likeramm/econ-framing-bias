# %% [markdown]
# # 03. 이벤트 스터디 & 주가 분석
#
# ## 목표
# - 경제 이벤트 발표 전후 주가 비정상 수익률(CAR) 분석
# - 그랜저 인과관계 검정
# - 매개 분석 (편향 → CCSI → 주가)

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import plotly.graph_objects as go

# %%
# TODO: 이벤트 스터디 분석 수행
