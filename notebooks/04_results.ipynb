# %% [markdown]
# # 04. 결과 정리 & 시각화
#
# ## 목표
# - 분석 결과 종합 정리
# - 논문/보고서용 시각화
# - 가설 검증 결과 요약

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
# TODO: 결과 정리 및 시각화
