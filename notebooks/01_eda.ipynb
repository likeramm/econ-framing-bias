# %% [markdown]
# # 01. 탐색적 데이터 분석 (EDA)
#
# ## 목표
# - 수집된 뉴스 기사 데이터 탐색
# - 언론사별 기사 분포 확인
# - 경제 이벤트별 기사 수 분석
# - 텍스트 기본 통계 (길이, 키워드 빈도 등)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
# TODO: 데이터 로드 및 EDA 수행
